# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
census_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'annual_salary']

# %%
df_census = pd.read_csv('adult.data', names=census_names)

# %%
df_census
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# To view frequency of each value for the column "race"

# %%
df_census['race'].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %% [markdown]
# Consider all individuals with education=Bachelors, race=White and sex=Male

# %%
df_white_male_b = df_census.loc[  (df_census['education']==' Bachelors') & (df_census['race']==' White') & (df_census['sex']==' Male') ]
df_white_male_b.head(10)
# Out:
#     age          workclass  fnlwgt   education  education_num  \
# 0    39          State-gov   77516   Bachelors             13
# 1    50   Self-emp-not-inc   83311   Bachelors             13
# 9    42            Private  159449   Bachelors             13
# 25   56          Local-gov  216851   Bachelors             13
# 32   45            Private  386940   Bachelors             13
# 41   53   Self-emp-not-inc   88506   Bachelors             13
# 42   24            Private  172987   Bachelors             13
# 53   50        Federal-gov  251585   Bachelors             13
# 60   30            Private   59496   Bachelors             13
# 72   29   Self-emp-not-inc  162298   Bachelors             13
#
#          marital_status        occupation    relationship    race    sex  \
# 0         Never-married      Adm-clerical   Not-in-family   White   Male
# 1    Married-civ-spouse   Exec-managerial         Husband   White   Male
# ...

# %% [markdown]
# Tuple Duplication:

# %% [markdown]
# To identify number of duplicate tuples in the data:

# %%
df_census.shape
# Out:
# (32561, 15)

# %%
df_census.duplicated(subset=None, keep=False).value_counts()
# Out:
# False    32514
# True        47
# Name: count, dtype: int64

# %% [markdown]
# Notes:
#
#     duplicated() returns a boolean series
#     subset=None considers all columns
#     keep=False marks all duplicates as "True"
#     Above dataset has 47 instances of duplicate tuples which can be removed
#
# To remove duplicate tuples

# %%
bool_series = df_census.duplicated(subset=None, keep=False)

# %%
df_census_unique = df_census[~bool_series]

# %%
print("Before removing duplicates:")
print(df_census.shape)
print("After removing duplicate tuples:")
print(df_census_unique.shape)
# Out:
# Before removing duplicates:
# (32561, 15)
# After removing duplicate tuples:
# (32514, 15)

# %% [markdown]
# **Data Integration**

# %%
dataset1=pd.read_csv("WorldCupMatches_new .csv")
dataset1.shape
# Out:
# (852, 20)

# %%
dataset2=pd.read_csv(("WorldCupMatches_new .csv"))
dataset2.shape
# Out:
# (852, 20)

# %% [markdown]
# Combin all files in the list

# %%
combined_csv = pd.concat([dataset1,dataset2])

# %% [markdown]
# Export To CSV

# %%
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
combined_csv.shape
# Out:
# (1704, 20)

# %% [markdown]
# **Data Reduction**
#
# Histogram

# %%
data=pd.read_csv('diamonds.csv')

# %%
plt.hist(data['cut'],color='blue',orientation ='vertical')
plt.title('cut histigram')
plt.xlabel('cut')
plt.ylabel('frequency')
cut=('ideal','Premium','Good','Very good','fair')
index=np.arange(len(cut))
plt.xticks(index,cut, rotation=90)
plt.show()

# %% [markdown]
# Correlation Analysis

# %%
data=pd.read_csv('diamonds.csv')

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data=data.filter(['carat', 'depth', 'table', 'x', 'y', 'z'])
data
# Out:
#        carat  depth  table     x     y     z
# 0       0.23   61.5   55.0  3.95  3.98  2.43
# 1       0.21   59.8   61.0  3.89  3.84  2.31
# 2       0.23   56.9   65.0  4.05  4.07  2.31
# 3       0.29   62.4   58.0  4.20  4.23  2.63
# 4       0.31   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0  5.75  5.76  3.50
# 53936   0.72   63.1   55.0  5.69  5.75  3.61
# 53937   0.70   62.8   60.0  5.66  5.68  3.56
# 53938   0.86   61.0   58.0  6.15  6.12  3.74
# 53939   0.75   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 6 columns]

# %%
data.corr()
# Out:
#           carat     depth     table         x         y         z
# carat  1.000000  0.028224  0.181618  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.195344  0.183760  0.150929
# x      0.975094 -0.025289  0.195344  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.970772  0.952006  1.000000

# %%
data.corr(method="pearson")
# Out:
#           carat     depth     table         x         y         z
# carat  1.000000  0.028224  0.181618  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.195344  0.183760  0.150929
# x      0.975094 -0.025289  0.195344  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.970772  0.952006  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(method="pearson"))
plt.show()
plt.savefig("heatmap_pearson.png")
plt.clf()
plt.close()

# %%
correlation_matrix = data.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
#demo of Histogram
from matplotlib import pyplot as plt
import numpy as np
fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a, bins = [0,50, 100])
ax.set_title("histogram of result")
ax.set_xticks([0,50, 100])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %%
plt.matshow(data.corr())
plt.xticks(range(len(data.columns)), data.columns)
plt.yticks(range(len(data.columns)), data.columns)
plt.colorbar()
plt.show()

# %% [markdown]
# **Data Transformation**

# %%
# converting and overwriting values in column
data["cut"]= data["cut"].str.lower()

# display
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ishan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cut'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
# ...

# %%
# converting and overwriting values in column
data["cut"]= data["cut"].str.upper()

# display
data.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       FAIR     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
# converting and overwriting values in column
data["cut"]= data["cut"].str.title()

# display
data.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
#Demo of Feature Encoding also converting categorical data into numbers
import pandas as pd
info = {
    'Gender' : ['male', 'female', 'female', 'male', 'female', 'female'],
    'Position' : ['CEO', 'Cleaner', 'Employee', 'Cleaner', 'CEO', 'Cleaner']
}
df = pd.DataFrame(info)
print(df)
# Out:
#    Gender  Position
# 0    male       CEO
# 1  female   Cleaner
# 2  female  Employee
# 3    male   Cleaner
# 4  female       CEO
# 5  female   Cleaner

# %%
#A LabelEncoder converts a categorical data into a number ranging from 0 to n-1,
#where n is the number of classes in the variable.
#These are represented as 0,1,2 in alphabetical order.
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
gender_encoded = le.fit_transform(df['Gender'])
print(gender_encoded)
# Out:
# [1 0 0 1 0 0]

# %%
df['encoded_gender'] = gender_encoded
print(df)
# Out:
#    Gender  Position  encoded_gender
# 0    male       CEO               1
# 1  female   Cleaner               0
# 2  female  Employee               0
# 3    male   Cleaner               1
# 4  female       CEO               0
# 5  female   Cleaner               0

# %%
encoded_position = le.fit_transform(df['Position'])
df['encoded_position'] = encoded_position
print(df)
# Out:
#    Gender  Position  encoded_gender  encoded_position
# 0    male       CEO               1                 0
# 1  female   Cleaner               0                 1
# 2  female  Employee               0                 2
# 3    male   Cleaner               1                 1
# 4  female       CEO               0                 0
# 5  female   Cleaner               0                 1

# %%
import numpy as np
Y = np.random.choice(('Male','Female'), size=(10))
Y
# Out:
# array(['Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male',
#        'Female', 'Male', 'Female'], dtype='<U6')

# %%
#one-hot encoding using LabelBinarizer class
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
Yb = lb.fit_transform(Y)

# %%
Yb
# Out:
# array([[1],
#        [1],
#        [0],
#        [1],
#        [1],
#        [0],
#        [1],
#        [0],
#        [1],
#        [0]])

# %%
lb.inverse_transform(Yb)
# Out:
# array(['Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male',
#        'Female', 'Male', 'Female'], dtype='<U6')

# %% [markdown]
# **DATA NORMALIZATION**

# %%
#Demo of Normaization -->normalizing we change the scale of the data. Data is most commonly rescaled to fall between 0-1.
from sklearn import preprocessing
import numpy as np
x_array = np.array([2,3,5,6,7,4,8,7,6])
normalized_arr = preprocessing.normalize([x_array])
print(x_array)
print(normalized_arr)
# Out:
# [2 3 5 6 7 4 8 7 6]
# [[0.11785113 0.1767767  0.29462783 0.35355339 0.41247896 0.23570226
#   0.47140452 0.41247896 0.35355339]]

# %%
#demo of Binning --> Let’s say we have an array of 10 random numbers from 1 to 100
import pandas as pd
import numpy as np

df_nums = pd.DataFrame({'num': np.random.randint(1, 100, 10)})
#df_nums = pd.DataFrame({'num': np.random.randint(1, 100, 5)})
print(df_nums)
# Out:
#    num
# 0   68
# 1   26
# 2   30
# 3   19
# 4   23
# 5   45
# 6   90
# 7   77
# 8   73
# 9   29

# %%
df_nums['num_bins'] = pd.cut(x=df_nums['num'], bins=[1, 25, 50, 75, 100])
#df['bins'] = pd.cut(x=df['number'], bins=[1, 20, 40, 60,80, 100])
print(df_nums)
# Out:
#    num   num_bins
# 0   68   (50, 75]
# 1   26   (25, 50]
# 2   30   (25, 50]
# 3   19    (1, 25]
# 4   23    (1, 25]
# 5   45   (25, 50]
# 6   90  (75, 100]
# 7   77  (75, 100]
# 8   73   (50, 75]
# 9   29   (25, 50]

# %%
print(df_nums['num_bins'].unique())
# Out:
# [(50, 75], (25, 50], (1, 25], (75, 100]]
# Categories (4, interval[int64, right]): [(1, 25] < (25, 50] < (50, 75] < (75, 100]]

# %%
data=pd.read_csv('diamonds.csv')
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
price_val = data['price']
price_val
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
normalized_price = (price_val - price_val.min())/(price_val.max()-price_val.min())
data['normalized_price']=normalized_price
data.sort_values(by='price')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
#        normalized_price
# ...

# %% [markdown]
# A Min-Max scaling is typically done via the following equation:
#
# Xsc=X−XminXmax−Xmin.

# %%
from sklearn import preprocessing

# %%
x = data[['price']].values.astype(float)
x.max()
# Out:
# 18823.0

# %%
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()
# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(data[['price']].values.astype(float))
# Run the normalizer on the dataframe
df_normalized = pd.DataFrame(x_scaled)
data['normalized2']=x_scaled
data.sort_values(by='price')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
#        normalized_price  normalized2
# ...

# %% [markdown]
# **Z-Score Normalization**

# %%
from scipy import stats
data['zscore']=stats.zscore(data['price'])
data.sort_values(by='price')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# ...
